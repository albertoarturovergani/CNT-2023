# %% [markdown]
# # Balanced network of excitatory and inhibitory neurons.
#
# An implementation of benchmarks from Brette et al. (2007) Journal of Computational Neuroscience 23: 349-398
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/ (see Fig. 24).
#
# In the paper, they compared simulations from NEST and NEURON. Here, we are going to simulate the balanced network with SpiNNaker.
#
# The network is based on the COBA models of Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/ .
#
# You can look also the explicit model in the supplementary material of Brette et al. (2007) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/#APP2

# %% [markdown]
# <img src="../extra/VA_EXC_SPIKES.png">

# %% [markdown]
# # step0: import the simulator

# %%
import socket
import spynnaker8 as sim
from pyNN.random import NumpyRNG, RandomDistribution
from pyNN.utility.plotting import Figure, Panel
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %% [markdown]
# # step1: setup the simulator

# %%
dt = 1          # (ms) simulation timestep
tstop = 1000      # (ms) simulaton duration
delay = 2 # (ms) 

sim.setup(
    timestep=dt, 
    min_delay=delay, 
    max_delay=delay) # [ms] # not that the max_delay supported by SpiNNaker is timestep * 144

rngseed = 98766987
rng = NumpyRNG(seed=rngseed, parallel_safe=True)
# Out:
# 2023-03-11 14:21:28 INFO: Read cfg files: /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/spinnaker/.spynnaker.cfg
# 2023-03-11 14:21:28 INFO: Will search these locations for binaries: /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2023-03-11 14:21:28 WARNING: /home/spinnaker/old/CNT-2023/SpiNNaker/reports has 28 old reports that have not been closed
# 2023-03-11 14:21:28 WARNING: /home/spinnaker/old/CNT-2023/SpiNNaker/application_generated_data_files has 29 old reports that have not been closed
# 2023-03-11 14:21:28 INFO: Setting time scale factor to 1.
# 2023-03-11 14:21:28 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/spinnaker/sPyNNaker/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/spinnaker/.spynnaker.cfg']

# %% [markdown]
# # step2: decide the cell types and parameters

# %%
# cell type
celltype = sim.IF_cond_exp
#  Leaky integrate and fire model with fixed threshold and exponentially-decaying post-synaptic conductance.
#  http://neuralensemble.org/docs/PyNN/_modules/pyNN/standardmodels/cells.html#IF_cond_exp
    
# Cell parameters
area = 20000.     # (µm²)
tau_m = 20.       # (ms)
cm = 1.           # (µF/cm²)
g_leak = 5e-5     # (S/cm²)

E_leak = None
E_leak = -60.  # (mV)
v_thresh = -50.   # (mV)
v_reset = -60.    # (mV)
t_refrac = 5.     # (ms) (clamped at v_reset)
v_mean = -60.     # (mV) mean membrane potential, for calculating CUBA weights
tau_exc = 5.      # (ms)
tau_inh = 10.     # (ms)
Erev_exc = 0.     # (mV)
Erev_inh = -80.   # (mV)

# === Calculate derived parameters ===
area = area * 1e-8                     # convert to cm²
cm = cm * area * 1000                  # convert to nF
Rm = 1e-6 / (g_leak * area)            # membrane resistance in MΩ
assert tau_m == cm * Rm                # just to check

cell_params = {'tau_m': tau_m,
               'tau_syn_E': tau_exc,
               'tau_syn_I': tau_inh,
               'v_rest': E_leak,
               'v_reset': v_reset,
               'v_thresh': v_thresh,
               'cm': cm,
               'tau_refrac': t_refrac,
               'i_offset': 0
               }

cell_params['e_rev_E'] = Erev_exc
cell_params['e_rev_I'] = Erev_inh

print(cell_params)
# Out:
# {'tau_m': 20.0, 'tau_syn_E': 5.0, 'tau_syn_I': 10.0, 'v_rest': -60.0, 'v_reset': -60.0, 'v_thresh': -50.0, 'cm': 0.2, 'tau_refrac': 5.0, 'i_offset': 0, 'e_rev_E': 0.0, 'e_rev_I': -80.0}

# %% [markdown]
# # step3: making cell populations

# %%
n = 1500          # number of cells
r_ei = 4.0        # number of excitatory cells:number of inhibitory cells
n_exc = int(round((n * r_ei / (1 + r_ei))))  # number of excitatory cells
n_inh = n - n_exc                            # number of inhibitory cells
print("{} {}".format(n_exc, n_inh))

pops = {
    'exc': sim.Population(
                                n_exc, 
                                celltype(**cell_params), 
                                label="Excitatory_Cells"),

    'inh': sim.Population(
                                n_inh, 
                                celltype(**cell_params), 
                                label="Inhibitory_Cells")
}

pops['exc'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])
pops['inh'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])


uniformDistr = RandomDistribution('uniform', [v_reset, v_thresh], rng=rng)
pops['exc'].initialize(v=uniformDistr)
pops['inh'].initialize(v=uniformDistr)

sim.set_number_of_neurons_per_core(sim.IF_cond_exp, 50)      # this will set
# 50 neurons per core
pops.keys()
# Out:
# 1200 300
# dict_keys(['exc', 'inh'])

# %% [markdown]
# # step4: define the synapse types

# %%
# Synapse parameters
Gexc = None
Ginh = None
Gexc = 4.     # (nS) #1
Ginh = 51.    # (nS) #1
w_exc = Gexc * 1e-3              # We convert conductances to uS
w_inh = Ginh * 1e-3

exc_synapses = sim.StaticSynapse(weight=w_exc, delay=delay)
inh_synapses = sim.StaticSynapse(weight=w_inh, delay=delay)

# %% [markdown]
# # step5: select the connections algorithm

# %%
pconn = 0.02      # connection probability (2%)

exc_conn = sim.FixedProbabilityConnector(pconn, rng=rng)
inh_conn = sim.FixedProbabilityConnector(pconn, rng=rng)

# %% [markdown]
# # step6: make the projections

# %%
connections = {
    
    'e2e': sim.Projection(
        pops['exc'],
        pops['exc'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'e2i': sim.Projection(
        pops['exc'], 
        pops['inh'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'i2e': sim.Projection(
        pops['inh'], 
        pops['exc'], 
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses),
    
    'i2i': sim.Projection(
        pops['inh'],
        pops['inh'],
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses)
    
        }

connections.keys()
# Out:
# dict_keys(['e2e', 'e2i', 'i2e', 'i2i'])

# %% [markdown]
# # step7: setting the thalamic stimulus

# %%
n_thalamic_cells = 20 
stim_dur = 50.    # (ms) duration of random stimulation
rate = 100.       # (Hz) frequency of the random stimulation

exc_conn = None

pops['thalamus'] = sim.Population(
    n_thalamic_cells, 
    sim.SpikeSourcePoisson(rate=rate, duration=stim_dur),
    label="expoisson")
pops['thalamus'].record("spikes")


rconn = 0.01
ext_conn = sim.FixedProbabilityConnector(rconn)

connections['ext2e'] = sim.Projection(
    pops['thalamus'], 
    pops['exc'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections['ext2i'] = sim.Projection(
    pops['thalamus'], 
    pops['inh'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections.keys(), pops.keys()
# Out:
# (dict_keys(['e2e', 'e2i', 'i2e', 'i2i', 'ext2e', 'ext2i']),
#  dict_keys(['exc', 'inh', 'thalamus']))

# %% [markdown]
# # step8: run simulation

# %%
tstop = 1000 # (ms)
sim.run(tstop)
# Out:
# 2023-03-11 14:21:32 INFO: Simulating for 1000 1.0ms timesteps using a hardware timestep of 1000us
# 2023-03-11 14:21:32 INFO: Starting execution process
# 2023-03-11 14:21:35 INFO: Time 0:00:02.791499 taken by SpallocMaxMachineGenerator
# Pre allocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:21:43 INFO: Time 0:00:08.793884 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:21:48 INFO: Time 0:00:04.851117 taken by PartitionAndPlacePartitioner
# Created spalloc job 7064698
# 2023-03-11 14:21:48 INFO: Created spalloc job 7064698
# Waiting for board power commands to complete.
# 2023-03-11 14:21:48 INFO: Waiting for board power commands to complete.
# 2023-03-11 14:21:57 INFO: Time 0:00:08.936993 taken by SpallocAllocator
# 2023-03-11 14:21:57 INFO: Creating transceiver for 10.11.193.1
# 2023-03-11 14:21:57 INFO: Working out if machine is booted
# 2023-03-11 14:22:01 INFO: Attempting to boot machine
# 2023-03-11 14:22:07 INFO: Found board with version [Version: SC&MP 3.2.5 at SpiNNaker:0:0:0 (built Thu Aug  1 08:15:06 2019)]
# 2023-03-11 14:22:07 INFO: Machine communication successful
# 2023-03-11 14:22:07 INFO: Detected a machine on IP address 10.11.193.1 which has 856 cores and 120.0 links
# 2023-03-11 14:22:07 INFO: Time 0:00:09.635183 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.009473 taken by PartitionerReport
# 2023-03-11 14:22:07 INFO: Time 0:00:00.000227 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.029164 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.026893 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.004638 taken by BoardChipReport
# Filtering edges
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.043624 taken by GraphEdgeFilter
# Placing graph vertices
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.036729 taken by OneToOnePlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.041215 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.008189 taken by DataInMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.004625 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.056047 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2023-03-11 14:22:07 INFO: Time 0:00:00.029670 taken by NerRoute
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.047633 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.008902 taken by TagReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.024254 taken by EdgeToNKeysMapper
# Getting constraints for application graph
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.030392 taken by ProcessPartitionConstraints
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.022428 taken by MallocBasedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.024263 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.022827 taken by BasicRoutingTableGenerator
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.043983 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:07 INFO: Time 0:00:00.028528 taken by BufferManagerCreator
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:08 INFO: Time 0:00:00.427402 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:08 INFO: Time 0:00:00.006203 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:08 INFO: Time 0:00:00.028750 taken by GraphBinaryGatherer
# Running routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:12 INFO: Time 0:00:04.526565 taken by MundyOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:12 INFO: Time 0:00:00.005846 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:12 INFO: Time 0:00:00.044115 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:13 INFO: Time 0:00:00.172956 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:18 INFO: Time 0:00:05.718197 taken by LoadSystemExecutableImages
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:18 INFO: Time 0:00:00.018692 taken by TagsLoader
# Writing data
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:18 INFO: Time 0:00:00.033523 taken by WriteMemoryIOData
# Executing data specifications and loading data for application vertices
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:19 INFO: Time 0:00:00.293133 taken by HostExecuteApplicationDataSpecification
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:23 INFO: Time 0:00:04.016485 taken by SynapseExpander
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:23 INFO: Time 0:00:00.060907 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:06.880519 taken by LoadApplicationExecutableImages
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.013566 taken by RoutingTableFromMachineReport
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.008254 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.008129 taken by comparisonOfRoutingTablesReport
# 2023-03-11 14:22:30 INFO: Running for 1 steps for a total of 1000.0ms
# 2023-03-11 14:22:30 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.065220 taken by SdramUsageReportPerChip
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.027917 taken by ChipRuntimeUpdater
# 2023-03-11 14:22:30 INFO: creating live event connection database in /home/spinnaker/old/CNT-2023/SpiNNaker/application_generated_data_files/2023-03-11-14-21-28-97084/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: Time 0:00:00.079969 taken by DatabaseInterface
# 2023-03-11 14:22:30 INFO: ** Notifying external sources that the database is ready for reading **
# 2023-03-11 14:22:30 INFO: Time 0:00:00.000945 taken by NotificationProtocol
# 2023-03-11 14:22:30 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:30 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2023-03-11 14:22:30 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2023-03-11 14:22:30 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2023-03-11 14:22:30 INFO: Application started; waiting 1.1s for it to stop
# 2023-03-11 14:22:31 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2023-03-11 14:22:31 INFO: Time 0:00:01.188135 taken by ApplicationRunner
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:35 INFO: Time 0:00:03.997785 taken by BufferExtractor
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:35 INFO: Time 0:00:00.103198 taken by GraphProvenanceGatherer
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:35 INFO: Time 0:00:00.042787 taken by PlacementsProvenanceGatherer
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:35 INFO: Time 0:00:00.054796 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2023-03-11 14:22:35 INFO: Time 0:00:00.040511 taken by ProfileDataGatherer
# 1000.0

# %% [markdown]
# # step9: save results in a folder

# %%
outputs = {}

for layer in ['exc', 'inh']:
    
    # save on the notebook space
    outputs[layer] = pops[layer].get_data()
    
    # save in the folder space
    for recording in ['v', 'gsyn_inh', 'gsyn_exc', 'spikes']:
        pops[layer].write_data(str(layer) + '_' + str(recording) + '.pkl')
# Out:
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting v for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_exc for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting gsyn_inh for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================

# %% [markdown]
# # step10: recover results

# %%
def recover_results(outputs):
    results = {}
    for key in outputs.keys(): # to extract the name of the layer, e.g., Exc, Inh, Thalamus, etc  
        
        # to get voltage and conductances
        for analogsignal in outputs[key].segments[0].analogsignals:
            print(key, analogsignal.name)
            results[key, analogsignal.name] = analogsignal

        # to get spikes
        results[key, 'spikes'] = outputs[key].segments[0].spiketrains
    return results

# check results
results = recover_results(outputs)
results.keys()
# Out:
# exc v
# exc gsyn_exc
# exc gsyn_inh
# inh v
# inh gsyn_exc
# inh gsyn_inh
# dict_keys([('exc', 'v'), ('exc', 'gsyn_exc'), ('exc', 'gsyn_inh'), ('exc', 'spikes'), ('inh', 'v'), ('inh', 'gsyn_exc'), ('inh', 'gsyn_inh'), ('inh', 'spikes')])

# %% [markdown]
# # step11: postprocessing (looking at the results)

# %%
from pyNN.utility.plotting import Figure, Panel
# %matplotlib inline

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(results['exc', 'spikes'], xlabel="Time/ms", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: excitatory cells spikes")

# %%
### from pyNN.utility.plotting import Figure, Panel
# %matplotlib inline
Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(results['inh', 'spikes'], xlabel="Time (ms)", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: inhibitory cells spikes")

# %%
# classic matplotlib rasterplot function

# %matplotlib inline
fig, ax = plt.subplots(2,1, sharex=True, figsize=(9,5))
p0=ax[0].eventplot(results['exc', 'spikes'], color='green')
p1=ax[1].eventplot(results['inh', 'spikes'], color='red')
[ax[i].set_xlabel('Time (ms)', fontsize=14) for i in [0,1]]
[ax[i].set_ylabel(feat, fontsize=14) for i, feat in enumerate(['Excitatory cells', 'Inhibitory cells'])]
# Out:
# [Text(0, 0.5, 'Excitatory cells'), Text(0, 0.5, 'Inhibitory cells')]

# %%
# check spikes

spike_rate = {
    'exc': pops['exc'].get_spike_counts(),
    'inh': pops['inh'].get_spike_counts()
}

idx=100
pop = 'exc'
print(pop + ' cell ' + str(idx) + ' :', spike_rate[pop][idx], 'spikes/' + str(tstop) + 'ms')
# Out:
# Getting spikes for Excitatory_Cells
# |0%                          50%                         100%|
#  ============================================================
# Getting spikes for Inhibitory_Cells
# |0%                          50%                         100%|
#  ============================================================
# exc cell 100 : 55 spikes/1000ms

# %%
# check conductances and membrane voltage potentials

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(1,3,figsize=(11,4), sharey=True, sharex=False)
ax = ax.flatten()
p=ax[0].hist(np.asarray(results['exc', 'v']).ravel(), 100, label='exc', log=False)
p=ax[1].hist(np.asarray(results['exc', 'gsyn_exc']).ravel(), 100, label='exc')
p=ax[2].hist(np.asarray(results['exc', 'gsyn_inh']).ravel(), 100, label='exc')

p=ax[0].hist(np.asarray(results['inh', 'v']).ravel(), 100, label='inh')
p=ax[1].hist(np.asarray(results['inh', 'gsyn_exc']).ravel(), 100, label='inh')
p=ax[2].hist(np.asarray(results['inh', 'gsyn_inh']).ravel(), 100, label='inh')

ax[0].set_xlim(-90,-40)
ax[1].set_xlim(0,0.2)
ax[2].set_xlim(0,0.5)

[ax[i].legend() for i in [0,1,2]]

[ax[i].set_ylabel('excitatory cells', fontsize=14) for i in [0,1,2]]
[ax[idx].set_xlabel(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]
# Out:
# [Text(0.5, 0, 'membrane potential [mV]'),
#  Text(0.5, 0, 'gsyn_exc [uS]'),
#  Text(0.5, 0, 'gsyn_inh [uS]')]

# %%
# voltage in excitatory pop

fig, ax = plt.subplots(1,3, figsize=(13,4), sharey=True, sharex=True)
ax = ax.flatten()

p = {}
for idx, feat in enumerate(['v', 'gsyn_exc', 'gsyn_inh']):
    p[idx] = ax[idx].imshow(np.asarray(results['exc', feat]).T,  norm=colors.PowerNorm(gamma= 0.75))

[fig.colorbar(p[idx], ax=ax[idx], shrink=0.5) for idx in [0,1,2]]

[ax[i].set_xlabel('time [ms]', fontsize=14) for i in [0,1,2]]
[ax[i].set_ylabel('excitatory cells', fontsize=14) for i in [0,1,2]]
[ax[idx].set_title(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]

p.keys()
# Out:
# dict_keys([0, 1, 2])

# %%
# voltage in inhibitory pop

fig, ax = plt.subplots(3,1, figsize=(11,11), sharey=True, sharex=False)
ax = ax.flatten()

p = {}
for idx, feat in enumerate(['v', 'gsyn_exc', 'gsyn_inh']):
    p[idx] = ax[idx].imshow(np.asarray(results['inh', feat]).T,  norm=colors.PowerNorm(gamma= 0.75))

[fig.colorbar(p[idx], ax=ax[idx], shrink=0.6) for idx in [0,1,2]]

[ax[i].set_xlabel('time [ms]', fontsize=14) for i in [0,1,2]]
[ax[i].set_ylabel('inhibitory cells', fontsize=14) for i in [0,1,2]]
[ax[idx].set_title(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]

rasterplot=True
if rasterplot:
    for i in [0,1,2]:
        ax[i].eventplot(results['inh', 'spikes'])

# %%
# signal processing step, statistics, information theory tools, etc

# %% [markdown]
# # step12: close simulation

# %%
# if you run it, you cannot reload some cells, but it is needed to restart the overall simulation

sim.end()
# Out:
# 2023-03-11 14:22:49 WARNING: A Timer tick callback was still executing when the next timer tick callback was fired off for Excitatory_Cells:0:254 on 0, 0, 3, 5 times. This is a sign of the system being overloaded and therefore the results are likely incorrect.  Please increase the machine time step or time_scale_factor or decrease the number of neurons per core
# 2023-03-11 14:22:49 WARNING: A Timer tick callback was still executing when the next timer tick callback was fired off for Excitatory_Cells:255:509 on 0, 0, 4, 6 times. This is a sign of the system being overloaded and therefore the results are likely incorrect.  Please increase the machine time step or time_scale_factor or decrease the number of neurons per core
# 2023-03-11 14:22:49 WARNING: A Timer tick callback was still executing when the next timer tick callback was fired off for Excitatory_Cells:510:764 on 0, 0, 5, 6 times. This is a sign of the system being overloaded and therefore the results are likely incorrect.  Please increase the machine time step or time_scale_factor or decrease the number of neurons per core
# 2023-03-11 14:22:49 WARNING: A Timer tick callback was still executing when the next timer tick callback was fired off for Excitatory_Cells:765:1019 on 0, 0, 6, 6 times. This is a sign of the system being overloaded and therefore the results are likely incorrect.  Please increase the machine time step or time_scale_factor or decrease the number of neurons per core
# 2023-03-11 14:22:49 WARNING: A Timer tick callback was still executing when the next timer tick callback was fired off for Inhibitory_Cells:0:254 on 0, 0, 8, 5 times. This is a sign of the system being overloaded and therefore the results are likely incorrect.  Please increase the machine time step or time_scale_factor or decrease the number of neurons per core

# %% [markdown]
# ## Task 1: on the self sustained acitivity conditions
#
# - in the image below, the panel a) shows the sustained activity conditions of the network. <br>
#   Try different set of weights combinations for discovering different functional network configurations
#
# <img src="./extra/VA_EXC_BALANCE.png">
#
# - image taken from Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/,
